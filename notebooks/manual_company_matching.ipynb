# %% [markdown]
# # MANUAL COMPANY MATCHING
#
# Name: Josemaria Macedo Carrillo\
# Created: 01/17/23\
# Last modified:\
# DSI
#
# The purpose of this notebook is to identify top Ukrainian agricultural exporters and checking if they match
# any of our known parent companies. If not we add them to our known companies dictionary ("KNOW_COMPANIES") of our "names.json" file.

# %%
import sys
sys.path.append('..')
import pandas as pd
from utils.plot import cargo_grouping
from config import ROOT_PATH
import os

# %% [markdown]
# We first import our data.

# %%
country = "spain"
file_name = f"total_exports_by_company_{country}.csv"
path = os.path.join(ROOT_PATH, "data", file_name)

# %%
country = "spain"
file_name = f"total_exports_by_company_{country}.csv"
path = os.path.join(ROOT_PATH, "data", file_name)
ig = pd.read_csv(path)

# %% [markdown]
# Then we get the top n companies exporting to Ukraine.

# %%
n = 50

tempo = cargo_grouping(ig, ["company_all"], ["weight_ton"], ["weight_ton"], True, {"weight_ton": "sum"})
tempo.sort_values(by=["weight_ton"], ascending=False)[:n]
# Out:
#                                      company_all  weight_ton
# 8                         Archer Daniels Midland  305326.560
# 76                               Viterra Ukraine  278390.438
# 38                                 Louis Dreyfus  223059.678
# 16                                       Cargill  111641.562
# 32                           Kernel Holding S.A.   95709.952
# 45                            New Logist Ukraine   91571.933
# 22                           Fin-Invest Polissia   79234.971
# 54  Public Investment Fund (PIF) of Saudi Arabia   77994.647
# 72             Ukrainian Agricultural Enterprise   76606.540
# 49                                          Olam   64967.265
# 33                                        Krauka   58462.708
# 11                               Astarta Holding   51819.745
# 37                                      Lintardo   45952.501
# 27            Industrial Milk Company (IMC) S.A.   45330.929
# 39                                      MHP S.E.   40092.420
# 62               Systemy Transportnykh Pokryttiv   37459.777
# 70                                       Trepfin   36439.186
# 47                                    Nika Trade   35656.080
# 75                                        Vilter   35304.750
# 35                         Likhachevsky Elevator   33425.695
# 15                                         COFCO   33259.500
# 26                                 Holdfins Layt   32110.109
# 34                                LNZ Group S.A.   31800.246
# 81                                   Zlata-Trade   30072.117
# 56                                  Renter Group   29392.041
# 43                                     Neko Oilz   29376.870
# 3                              Agrotech-Garantia   29296.740
# 36                                     Limbo Pro   27849.230
# 10                                        Askano   27135.683
# 48                        Niva Pereyaslavshchyny   24958.950
# 55                                     Raykomiia   24916.855
# 65                                       Taraban   24339.260
# 74                                        Vilker   23595.060
# 69                                Transit Agro-M   23507.740
# 2                              Agrofirma Rokytne   22822.920
# 20                                 Elevator Agro   22418.058
# 66                                  Tavamis Hrup   22408.133
# 1                              Agrofirm Svitanok   21259.694
# 42                              NCH Capital Inc.   20862.013
# 18                                Company Farmco   20627.373
# 73                                   Venom Grain   19890.280
# 0                                    Agro-region   19651.242
# 77                                 Vizmir Market   18228.021
# 17                              Chysta Krynytsia   17096.524
# 58                                 Sanlex Invest   16992.260
# 7                                   Amedia Group   16653.305
# 53       Private Agricultural Enterprise Ukraine   16051.312
# 21                                Epicentr-K LLC   15952.000
# 28                                     Interflot   15795.222
# 59                                      Senteotl   15549.070

# %% [markdown]
# Then we get the full company name.

# %%
tempo.loc[59]["company_all"]
# Out:
# 'Senteotl'

# %% [markdown]
# We double check that the company is actually exporting crops to confirm we filtered the IG dataset correctly with companies that only export agricultural products that appear in BSGI.

# %%
ig[ig["shipper"] == 'ТОВ ЗЕМЛЯ І ВОЛЯ 17400 ЧЕРНІГІВСЬКА ОБЛ М БОБРОВИЦЯ ВУЛ ЧЕРНІГІВСЬКА 34']["product"]

# %% [markdown]
# We check if there are any name matches with the Land Matrix company parents we found
# in Land Matrix.
#
# First we get the Land Matrix data.

# %%
deals = pd.read_csv("../data/land_matrix/deals.csv", delimiter=";")
deals_c = deals.copy()
deals_c.loc[:, "country_low"] = deals_c.loc[:, "Target country"].str.lower()
deals_c = deals_c.loc[deals_c.loc[:, "country_low"].str.contains("ukraine", na=False)]
deals_c["Target country"]
# Out:
# /var/folders/j4/m2rbwhqs6yq26cq7rc0g4cm80000gn/T/ipykernel_58136/99570549.py:1: DtypeWarning: Columns (139) have mixed types. Specify dtype option on import or set low_memory=False.
#   deals = pd.read_csv("../data/land_matrix/deals.csv", delimiter=";")
# 572     Ukraine
# 573     Ukraine
# 574     Ukraine
# 575     Ukraine
# 576     Ukraine
#          ...
# 6461    Ukraine
# 6462    Ukraine
# 6463    Ukraine
# 6464    Ukraine
# 6467    Ukraine
# Name: Target country, Length: 358, dtype: object

# %% [markdown]
# Then we look for companies matches manually in Land Matrix data.

# %%
company_str = "vol"
deals_c[deals_c["Top parent companies"].str.lower().str.contains(company_str)]["Top parent companies"]
# Out:
# 2425                          Volynzernoproduct LLC#5023#
# 3659    Alberto Kazoni#5062#|Kyrylenko Volodymyr#5063#...
# 4707    Johann Yager Jacob#41994#|Venhri Agrar#41995#|...
# 5527                          Volodarsk Inagro LLC#43420#
# 6163    Chuikevych Volodymyr#44276#|Karbovnichyi Andri...
# Name: Top parent companies, dtype: object

# %%
sorted(deals_c["Top parent companies"].unique())
# Out:
# ['AGR Invest Holding Ltd#40757#',
#  'AGT Capital Management Ltd.#41248#',
#  'Agro Ukraina AB#44407#',
#  'Agro-Podillya i K LLC#43419#',
#  'AgroGeneration#656#',
#  'AgroGeneration#656#|Azent Ltd.#40783#',
#  'AgroGeneration#656#|L`ost Dominic#41121#|Mandua Catrin#41123#|Claud Mandua#41124#',
#  'Agromino A/S#4970#',
#  'Agroton Public Limited#38647#',
#  'Agrovista Limited#41491#',
#  'Akella Impex LP#5042#',
#  'Aladin tekstil ve hiyim iuriunleri tidzharet LLC#44904#',
#  'Alberto Kazoni#5062#|Kyrylenko Volodymyr#5063#|Vorotyntsev Vitaliy#5064#',
#  'Albus Gunter#41907#',
#  'Alexander Wolters#41898#',
#  'Alpha-Capital LLC#44409#',
#  'Aslan Global Management#1779#',
#  'BKW Group LLC#43027#',
#  'Berend Popke van der Velde#40762#|Herrit Tonkens#40763#|Huzinha Kornelius Hendrick#40764#|Oxana Kryachko#40765#',
#  'Berry Farma ApS#5060#',
#  'Bitex Trade Ltd.#43046#',
#  'Bontrup Holding#4963#',
#  'Brunner&Partner LLC#5047#|Glendore Holding LLC#5048#',
#  "Brykivs'ke LLC#43422#",
#  'CNBM International energy PTE.LTD#44677#',
#  'Cacique Limited#5027#',
#  'Chinese Agricultural Corporation HuanFan Qu#3544#',
#  'Chuikevych Volodymyr#44276#|Karbovnichyi Andrii#44277#',
#  'Closed non-diversified venture capital investment fund Konditerinvest#44422#',
#  'Creative Group#35578#',
#  'DTEK RENEWABLES FINANCE B.V.#44549#',
#  'DTEK Renewables B.V.#41134#',
#  'DUI Holding A/S#3891#',
#  'Dal Bianco Nazzareno#5061#',
#  'Delfs  Klaus#41926#',
#  'Denkhart Rodger Dean#40909#',
#  'Drul Oxana Romanivna#41057#|Hladun Yuriy Yevgenovych#41058#|Ovcharuk Valeriy Ivanovych#41059#|Sikorskyi Vitaliy Petrovych#41060#',
#  'ED&F Man Land Investments Ukraine B.V.#4547#',
#  'EMERGY AS#44003#',
#  'East Capital#5055#',
#  'Elementum (UK) I Limited LLC#44663#',
#  'Eridon PE#44435#',
#  'Farmgate B.V.#41990#',
#  'Fintest trading co limited#44694#|Ivory trade ITD.#44695#|Inkosteel group LLC#44696#',
#  'Granush Limited#44419#',
#  'Group of companies Vitagro LLC#40579#',
#  'Guris Insaat#41092#|Mogan International#41093#',
#  'HC Windparks Ukraine limited#44603#|LLC Managment compani "WPV"#44629#',
#  'HTKF GmbH & Co. KG#41896#',
#  'Heinrich Bokelo#41916#',
#  'Industrial Milk Company (IMC) S.A.#4782#',
#  'Industrial Milk Company (IMC) S.A.#4782#|Burat-Agro LLC#40724#',
#  'Industrial Milk Company (IMC)#3546#',
#  'Iranian State#2374#',
#  'Ivanchyk V.P.#42381#|Fairfax Financial Holdings LTD#42382#',
#  'JSC "TAS Group"#902#',
#  'Johann Yager Jacob#41994#|Venhri Agrar#41995#|Khmelnytske ATP 16854 PrJSC#41997#|Izbinskyy Ivan Volodymyrovych#41998#',
#  'Johannes Kluth#41924#',
#  'Johannes Ventsl#5053#',
#  'KSG Agro SA#3146#',
#  'KSG Agro SA#3146#|Xinjiang Production and Construction Corps (XPCC)#3147#|China National Corporation for Overseas Economic Cooperation#3148#|China-Ukraine International Engineering Cooperation Association Ltd.#3149#',
#  'Kernel Holding S.A.#908#',
#  'Kernel Holding S.A.#908#|Jerste S.a.r.l.#40585#',
#  'Kernel Holding S.A.#908#|Jerste S.a.r.l.#40585#|Agrofirm "Hliborob" LLC#41493#|Asset managment company "Progressive investment strategies" LLC#41501#|Bandurka OEP LLC#41502#',
#  'Kernel Holding S.A.#908#|Kalyna LLC#39628#|Jerste S.a.r.l.#40585#',
#  'Kintayer KTF LLC#40760#',
#  'Korol Anzhela Victorivna#41253#',
#  'Kozak Bohdan#41944#|Neimair Verner Eduard#41945#|Luff Karin Mariia#41946#',
#  'Kozitskyi Zinoviy Yaroslavovych#44675#',
#  'Kumari Ruchika#5043#',
#  'Kusto Agro Farming LLC#43464#',
#  'Kusto Group Inc.#4427#',
#  'LNZ Group S.A.#44411#',
#  'Lampka Zigmund Gustav#5049#',
#  'MCB Agricole#909#',
#  'MHP S.E.#4779#',
#  'MHP S.E.#4779#|Raftan Holding Limited#41434#',
#  'MHP S.E.#4779#|Stock company "Closed non-diversified venture corporate investment fund"Yukon" (SC "Yukon")#41442#',
#  'Magyar Farming Company Ltd#5065#',
#  'Malyhina Tetiana#44280#',
#  'Mark Carlel Amedee Wan Goi#5026#',
#  'Michael Dilman#41873#|Maier Benedict Kornelius Karolus#41877#|Klaus Vilhelm Dilman#41879#',
#  'Michael Matthias Heinrich#40618#',
#  'Michel Tereshchenko#40514#',
#  'Moritz Stamm#42000#',
#  'Mriya Agro Holding Public Limited#3867#|MES Invest B.V.#40681#',
#  'Myronivsky Hliboproduct PJSC#3525#|MHP S.E.#4779#',
#  'Myronivsky Hliboproduct PJSC#3525#|MHP S.E.#4779#|Stock company "Closed non-diversified venture corporate investment fund"Yukon" (SC "Yukon")#41442#|"Vinnytska Ptakhofabryka" LLC#41512#|STVO "Starynska Ptakhofabryka"#41513#|"LK Ukraine Group" LLC#41534#',
#  'NCH Capital Inc.#3521#',
#  'NCH Capital Inc.#3521#|LU Invest#40609#',
#  'Nibulon#3545#',
#  'Noymeier Rudolf Mikhael#41869#',
#  'Obora Zoryana#44464#',
#  'Paladium Kapital LLC#41118#',
#  'Petersen Nils#41948#',
#  'Phoenix Green Farms B.V.#5044#',
#  'Primorskaya WEP B.V.#44547#',
#  'Private agricultiural enterrise "Nove Zhyttya" LLC#44414#',
#  'Public Investment Fund (PIF) of Saudi Arabia#3112#',
#  'Public Investment Fund (PIF) of Saudi Arabia#3112#|Almarai#4979#|Saudi Grain and Fodder Holding Co. LC#40508#',
#  'Purple Pearl Limited#42254#',
#  'Qatar Investment Authority#376#',
#  'Renvior Trading Limited#5029#|Epicentr-K LLC#5030#',
#  'Renvior Trading Limited#5029#|Epicentr-K LLC#5030#|Logistical centre Kalynivka PJSC#5031#|Nova Linia PJSC#5032#|Agroholdyng 2012 LLC#5033#',
#  'Resilient JSC#5074#',
#  'Rohini Finch#41221#|Apex Trust Company Limited#41222#',
#  'Roland Wagner#41909#|Kostyantyn Wagner#41910#',
#  'SAS Investcompagnie#42875#',
#  'SC KMR France#42307#',
#  'Serhiy Globenko#44465#',
#  'Serhiy Hrynko#44466#',
#  'Shandong Shangshi Ecological Agriculture Technology Co., Ltd#41165#',
#  'Shelukhin family#42996#',
#  'Shumilkin Family#44456#',
#  'Sintal Agriculture Plc#3866#',
#  'Stern&Co LLC#40965#',
#  'Stevedoring company Olvia#44426#',
#  'Swiss Sustainable Agri Holdings II B.V.#44340#',
#  'System Capital Management (SCM)#3530#|Smart Holding#3531#',
#  'TNA Corporate Solutions LLC#41929#',
#  'TS&TS Ahrar GmbH& Co. KG#41967#',
#  'Terra Food Milk Ukraine Limited#44050#',
#  'The Besana Group#41286#',
#  'Tomas Mayers#5052#',
#  'Tommy International Trading Limited#41504#|Mostipan Olexander#41505#',
#  'Transcarpatia GmbH&Co. KG#41928#',
#  'U LINCZIN#41382#',
#  'Uagro Beteiligungs GmbH#41881#',
#  'UkrLandFarming PLC#3528#',
#  'UkrLandFarming PLC#3528#|Extrar Holding Limeted#42100#',
#  'Ukraina Nova LLC#39721#',
#  'Ukraine Invest A/S#40754#|World Bank#41507#',
#  'Ukraine renewable energy holdings UREH limited#44655#',
#  'Ukrainian Agrarian Holding#44410#',
#  'Vita Genero Limited#42151#',
#  'Volodarsk Inagro LLC#43420#',
#  'Volynzernoproduct LLC#5023#',
#  'Western NIS Enterprise Fund#4708#',
#  'Wideline Business Limited#5021#',
#  'Wingcraft holdings limited#44559#',
#  'YUTS-Agroproduct LLC#42080#',
#  'Yaher Tonnis Chapko#42020#|PJSC "Proskuriv"#42022#',
#  'Yelyseysʹki polya LLC (Champs Elysées)#43899#',
#  'ZH Capital Ltd#43406#|Murelli Investment LTD#43407#']
